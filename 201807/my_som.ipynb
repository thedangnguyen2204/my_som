# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('Credit_Card_Applications.csv')

# %%
dataset
# bai toan tim ra cac tai khoan ngan hang loi, bang cach tim ra cac outliers, 
# cot class la tai khoan do da duoc approval hay chua, neu tai khoan co loi ma duoc approval thi se nguy hiem
# Out:
#      CustomerID  A1     A2      A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  \
# 0      15776156   1  22.08  11.460   2   4   4  1.585   0   0    0    1    2
# 1      15739548   0  22.67   7.000   2   8   4  0.165   0   0    0    0    2
# 2      15662854   0  29.58   1.750   1   4   4  1.250   0   0    0    1    2
# 3      15687688   0  21.67  11.500   1   5   3  0.000   1   1   11    1    2
# 4      15715750   1  20.17   8.170   2   6   4  1.960   1   1   14    0    2
# 5      15571121   0  15.83   0.585   2   8   8  1.500   1   1    2    0    2
# 6      15726466   1  17.42   6.500   2   3   4  0.125   0   0    0    0    2
# 7      15660390   0  58.67   4.460   2  11   8  3.040   1   1    6    0    2
# 8      15663942   1  27.83   1.000   1   2   8  3.000   0   0    0    0    2
# 9      15638610   0  55.75   7.080   2   4   8  6.750   1   1    3    1    2
# 10     15644446   1  33.50   1.750   2  14   8  4.500   1   1    4    1    2
# ...

# %%
# Id de tim ra tai khoan loi
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
X
# Out:
# array([[1.5776156e+07, 1.0000000e+00, 2.2080000e+01, ..., 2.0000000e+00,
#         1.0000000e+02, 1.2130000e+03],
#        [1.5739548e+07, 0.0000000e+00, 2.2670000e+01, ..., 2.0000000e+00,
#         1.6000000e+02, 1.0000000e+00],
#        [1.5662854e+07, 0.0000000e+00, 2.9580000e+01, ..., 2.0000000e+00,
#         2.8000000e+02, 1.0000000e+00],
#        ...,
#        [1.5675450e+07, 0.0000000e+00, 1.8830000e+01, ..., 2.0000000e+00,
#         1.0000000e+02, 1.0000000e+00],
#        [1.5776494e+07, 0.0000000e+00, 2.7420000e+01, ..., 2.0000000e+00,
#         1.2000000e+02, 1.2000000e+01],
#        [1.5592412e+07, 1.0000000e+00, 4.1000000e+01, ..., 1.0000000e+00,
#         5.6000000e+02, 1.0000000e+00]])

# %%
for x in X:
    print(x[0])
# Out:
# 15776156.0
# 15739548.0
# 15662854.0
# 15687688.0
# 15715750.0
# 15571121.0
# 15726466.0
# 15660390.0
# 15663942.0
# 15638610.0
# 15644446.0
# 15585892.0
# 15609356.0
# 15803378.0
# 15599440.0
# 15692408.0
# 15683168.0
# 15790254.0
# 15767729.0
# 15768600.0
# 15699839.0
# 15786237.0
# 15694530.0
# 15796813.0
# 15605791.0
# 15714087.0
# 15711446.0
# 15588123.0
# 15748552.0
# 15618410.0
# 15672432.0
# 15610042.0
# 15580914.0
# 15583680.0
# 15813718.0
# 15767264.0
# 15686461.0
# 15678882.0
# 15789611.0
# 15668679.0
# 15631685.0
# 15655658.0
# 15753591.0
# 15617348.0
# 15704581.0
# 15738487.0
# 15648069.0
# 15737627.0
# 15731586.0
# 15757467.0
# 15597709.0
# 15720529.0
# 15596797.0
# 15681755.0
# 15815271.0
# 15682860.0
# 15621546.0
# 15705918.0
# 15684512.0
# 15671769.0
# 15642934.0
# 15594305.0
# 15789201.0
# 15706762.0
# 15766183.0
# 15777994.0
# 15568162.0
# 15680643.0
# 15761854.0
# 15730793.0
# 15692137.0
# 15608595.0
# 15709459.0
# 15775750.0
# 15585855.0
# 15752139.0
# ...

# %%
# Features scaling (cho cac feature trong khoang 0-1)
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range = (0, 1))
X = sc.fit_transform(X)
X
# Out:
# array([[8.42681467e-01, 1.00000000e+00, 1.25263158e-01, ...,
#         5.00000000e-01, 5.00000000e-02, 1.21200000e-02],
#        [6.96090562e-01, 0.00000000e+00, 1.34135338e-01, ...,
#         5.00000000e-01, 8.00000000e-02, 0.00000000e+00],
#        [3.88981656e-01, 0.00000000e+00, 2.38045113e-01, ...,
#         5.00000000e-01, 1.40000000e-01, 0.00000000e+00],
#        ...,
#        [4.39420332e-01, 0.00000000e+00, 7.63909774e-02, ...,
#         5.00000000e-01, 5.00000000e-02, 0.00000000e+00],
#        [8.44034934e-01, 0.00000000e+00, 2.05563910e-01, ...,
#         5.00000000e-01, 6.00000000e-02, 1.10000000e-04],
#        [1.06907888e-01, 1.00000000e+00, 4.09774436e-01, ...,
#         0.00000000e+00, 2.80000000e-01, 0.00000000e+00]])

# %%
# Train the SOM
from minisom import MiniSom

# %%
som = MiniSom(x = 10, y = 10, input_len=15, sigma=1.0, learning_rate=0.5)
som.random_weights_init(X)
som.train_random(X, num_iteration=100)

# %%
#Visualize the result
from pylab import bone, pcolor, colorbar, plot, show

# %%
bone()
pcolor(som.distance_map().T)
colorbar()

# %%
som.distance_map()
# Out:
# array([[0.14353042, 0.27782684, 0.39392784, 0.5674739 , 0.60597472,
#         0.75975791, 0.56042081, 0.4939763 , 0.382109  , 0.21789279],
#        [0.28989532, 0.5098331 , 0.58315002, 0.76100845, 0.90628631,
#         0.95561641, 1.        , 0.72182777, 0.76678904, 0.48507106],
#        [0.45408895, 0.65500006, 0.65204068, 0.65270404, 0.66614503,
#         0.91741058, 0.90609297, 0.86315528, 0.83303668, 0.50127858],
#        [0.30740237, 0.49935865, 0.50237421, 0.50894702, 0.64746583,
#         0.82008639, 0.91589687, 0.76037021, 0.8387856 , 0.44150672],
#        [0.26370481, 0.39252226, 0.4173655 , 0.52641797, 0.55279551,
#         0.65431597, 0.75228132, 0.81509408, 0.78248918, 0.54981323],
#        [0.34261606, 0.55246576, 0.52834218, 0.57454877, 0.62401164,
#         0.59967106, 0.58907979, 0.70600549, 0.72435958, 0.46046275],
#        [0.32807718, 0.47235575, 0.61063963, 0.61463792, 0.67831887,
#         0.65073174, 0.7192509 , 0.60748689, 0.65558591, 0.28208153],
# ...

# %%
bone()
pcolor(som.distance_map().T)
colorbar()
markers = ['o', 's']
colors = ['r', 'g']
# i is the index in X, x is each vector in each iteration
for i, x in enumerate(X):
    w = som.winner(x) # find the winning node for vector x
    plot(w[0] + 0.5,
         w[1] + 0.5,
         markers[y[i]],
         markeredgecolor = colors[y[i]],
         markerfacecolor = 'None',
         markersize = 10,
         markeredgewidth = 2)
show()

# %%
# Find the frauds
mappings = som.win_map(X)
mappings[(2,9)]
# SOM đánh số trục tọa độ từ 0
# Out:
# []

# %%
frauds = np.concatenate((mappings[(7,2)], mappings[(4,2)]), axis=0)
frauds = sc.inverse_transform(frauds)
frauds
# Out:
# array([[1.5591010e+07, 1.0000000e+00, 4.7830000e+01, 4.1650000e+00,
#         2.0000000e+00, 1.4000000e+01, 5.0000000e+00, 8.5000000e-02,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         2.0000000e+00, 5.2000000e+02, 1.0000000e+00],
#        [1.5590234e+07, 1.0000000e+00, 2.2080000e+01, 8.3000000e-01,
#         2.0000000e+00, 8.0000000e+00, 8.0000000e+00, 2.1650000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         2.0000000e+00, 1.2800000e+02, 1.0000000e+00],
#        [1.5642448e+07, 1.0000000e+00, 2.7670000e+01, 7.5000000e-01,
#         2.0000000e+00, 1.1000000e+01, 8.0000000e+00, 1.6500000e-01,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         2.0000000e+00, 2.2000000e+02, 2.5200000e+02],
#        [1.5620832e+07, 1.0000000e+00, 3.7330000e+01, 2.6650000e+00,
#         2.0000000e+00, 1.3000000e+01, 4.0000000e+00, 1.6500000e-01,
# ...

# %%
som.winner(mappings[(7,2)][0])
# Out:
# (7, 2)

# %%
print(sc.inverse_transform([mappings[(7,2)][0]]))
print(sc.inverse_transform([mappings[(7,2)][1]]))
# Out:
# [[1.559101e+07 1.000000e+00 4.783000e+01 4.165000e+00 2.000000e+00
#   1.400000e+01 5.000000e+00 8.500000e-02 0.000000e+00 0.000000e+00
#   0.000000e+00 1.000000e+00 2.000000e+00 5.200000e+02 1.000000e+00]]
# [[1.5590234e+07 1.0000000e+00 2.2080000e+01 8.3000000e-01 2.0000000e+00
#   8.0000000e+00 8.0000000e+00 2.1650000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 1.0000000e+00 2.0000000e+00 1.2800000e+02 1.0000000e+00]]

# %%
qnt = som.quantization(X)

# %%
qnt[133]
# Out:
# array([0.37883784, 0.62109941, 0.15822059, 0.07160364, 0.32460167,
#        0.43563222, 0.25881148, 0.03760714, 0.05112784, 0.06667343,
#        0.0024467 , 0.01926376, 0.25483439, 0.06810684, 0.00127867])

# %%
qnt[147]
# Out:
# array([0.43494982, 0.13715128, 0.15431984, 0.23608617, 0.44505473,
#        0.22335324, 0.42402356, 0.01490412, 0.12177588, 0.14360387,
#        0.00606604, 0.10155957, 0.48215414, 0.07861528, 0.00477947])
