# %%
import numpy as np
from sklearn.metrics import euclidean_distances
import pandas as pd
import minisom
import LVQ

# %%
data = pd.read_csv(r"../data/SD-2X_rocktype.csv")
x = data.iloc[:, 0:6].values
y = data.iloc[:, 6].values
y[y==4] = 0
from sklearn.cross_validation import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.1, random_state=44)

# use Minmaxscaler because we use euclidean distance
from sklearn.preprocessing import MinMaxScaler
minmax = MinMaxScaler()
x_train = minmax.fit_transform(x_train)
x_test = minmax.transform(x_test)

# %%
# Training the SOM
from minisom import MiniSom
som = MiniSom(x = 10, y = 10, input_len = 6, sigma = 1.0, learning_rate = 0.5)
som.random_weights_init(x_train)
som.train_random(data = x_train, num_iteration = 100)

# %%
labels = np.zeros((4, 10, 10))
propa = np.zeros((4, 10, 10))

# %%
# Visualizing the results
from pylab import bone, pcolor, colorbar, plot, show
bone()
pcolor(som.distance_map().T)
colorbar()
markers = ['v', 's', 'o', '4']
colors = ['r', 'g', 'b', 'y']
for i, x in enumerate(x_train):
    w = som.winner(x)
    plot(w[0] + 0.5,
         w[1] + 0.5,
         markers[y_train[i]],
         markeredgecolor = colors[y_train[i]],
         markerfacecolor = 'None',
         markersize = 10,
         markeredgewidth = 2)
    if y_train[i] == 0:
        labels[0, w[0], w[1]] += 1
    elif y_train[i] == 1:
        labels[1, w[0], w[1]] += 1
    elif y_train[i] == 2:
        labels[2, w[0], w[1]] += 1
    elif y_train[i] == 3:
        labels[3, w[0], w[1]] += 1
show()

# %%
for i in range(4):
    for j in range(10):
        for k in range(10):
            total = labels[0, j, k] + labels[1, j, k] + labels[2, j, k] + labels[3, j, k]
            if total == 0. :
                continue
            else:
                propa[i, j, k] = labels[i, j, k] / total
                propa[i, j, k] = round(propa[i, j, k], 2)

# %%
p_vectors = som.weights
# Out:
# array([[[0.37338799, 0.38444669, 0.45428527, 0.51947117, 0.33120342,
#          0.35617558],
#         [0.34248523, 0.39939036, 0.39957016, 0.52791289, 0.28115528,
#          0.45364589],
#         [0.42445617, 0.37716229, 0.40122854, 0.51372522, 0.35718787,
#          0.35370107],
#         [0.40658275, 0.32741693, 0.49121205, 0.4493452 , 0.49137208,
#          0.20698237],
#         [0.34183548, 0.3851822 , 0.50333532, 0.46093551, 0.39706639,
#          0.33363673],
#         [0.40898114, 0.3951724 , 0.42195009, 0.52882048, 0.42136193,
#          0.20330848],
#         [0.42575987, 0.42040403, 0.42858812, 0.52121701, 0.3747572 ,
#          0.21492108],
#         [0.3931083 , 0.46273972, 0.33002198, 0.57085816, 0.30854155,
#          0.31834947],
#         [0.34948917, 0.48608639, 0.258336  , 0.58715673, 0.23974811,
#          0.4154608 ],
#         [0.32002604, 0.49594596, 0.21655546, 0.58887333, 0.2244977 ,
#          0.45558056]],
#
#        [[0.32816304, 0.38590571, 0.38657203, 0.55293614, 0.21458644,
#          0.49209974],
#         [0.32521436, 0.39209871, 0.41294989, 0.51219011, 0.21506438,
#          0.51124868],
#         [0.32484894, 0.39504975, 0.39130252, 0.52679295, 0.23476959,
#          0.50265656],
#         [0.36215183, 0.39845722, 0.39423113, 0.53613708, 0.3901654 ,
#          0.33909838],
#         [0.39425519, 0.39487723, 0.35119459, 0.53951442, 0.47343606,
#          0.22378489],
#         [0.41481968, 0.39309533, 0.39935656, 0.52533399, 0.45520661,
#         [0.38099512, 0.40723206, 0.49016951, 0.50828468, 0.3602416 ,
#          0.2461936 ],
#         [0.3426491 , 0.35936917, 0.59491229, 0.43544014, 0.41517308,
#          0.19377298],
#         [0.24997002, 0.23716435, 0.81724688, 0.2988883 , 0.3183271 ,
#          0.15069584],
#         [0.09767405, 0.11808998, 0.9445197 , 0.17529961, 0.13221323,
#          0.19022823],
#         [0.19609012, 0.25941304, 0.81753239, 0.34660287, 0.18294641,
#          0.26887058]],
#
#        [[0.16138583, 0.18285493, 0.85227261, 0.2840515 , 0.22033134,
#          0.29140853],
#         [0.31939647, 0.29117779, 0.65851758, 0.4130327 , 0.4019228 ,
#          0.21775682],
#         [0.41077304, 0.28963436, 0.6093073 , 0.38494329, 0.47357829,
#          0.06053374],
#         [0.42037167, 0.30244357, 0.6021058 , 0.41393037, 0.42833412,
#          0.12031491],
#         [0.38413651, 0.37495253, 0.51858236, 0.4805716 , 0.41254956,
#          0.20439149],
#         [0.32068336, 0.35479648, 0.58736311, 0.40502065, 0.38068799,
#          0.34252175],
#         [0.33576976, 0.38188473, 0.53929699, 0.45864547, 0.43692936,
#          0.22207779],
#         [0.28305211, 0.30476031, 0.7387896 , 0.37318176, 0.30803889,
#          0.21688707],
#         [0.20891323, 0.2519021 , 0.8116539 , 0.34445501, 0.21750944,
#          0.26107266],
#         [0.25988234, 0.24105433, 0.76801744, 0.3695221 , 0.35338339,
#          0.15191047]]])

# %%
taggings = np.zeros((10, 10))
for i in range(10):
    for j in range(10):
        tmp = np.array([labels[0][i][j], labels[1][i][j], labels[2][i][j], labels[3][i][j]])
        sort = tmp.argsort()
        if (tmp[sort[3]] <= tmp[sort[2]] * 5): # must be improve
            taggings[i][j] = np.random.choice([sort[3], sort[2]])
        else:
            taggings[i][j] = sort[3]

# %%
def find_closest(in_vector, proto_vectors, labels):
    """
    Find the closest prototype vector for a given vector

    Parameters
    -------
    in_vector: the given vector
    proto_vectors: the set of prototype vectors
    """
    closest_distance = 99999
    for i in range(10):
        for j in range(10):
            if (labels[0, i, j] == 0 and labels[1, i, j] == 0 and labels[2, i, j] == 0 and labels[3, i, j] == 0):
                continue
            else:
                distance = np.linalg.norm(in_vector - proto_vectors[i][j])
                if distance < closest_distance:
                    closest_distance = distance
                    closest = (i, j)         
    return closest

# %%
def predict(test_vector, p, taggings, labels):
    position = find_closest(test_vector, p, labels)
    return taggings[position[0], position[1]]

# %%
predicted_y1 = [predict(instance, p_vectors, taggings, labels) for instance in x_test]

from sklearn.metrics import classification_report

print (classification_report(y_test, predicted_y1, target_names=['0','1', '2', '3']))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.92      0.91      0.92        54
#           1       1.00      0.61      0.76        23
#           2       0.21      0.62      0.31         8
#           3       0.78      0.68      0.73        47
#
# avg / total       0.84      0.76      0.78       132

# %%
data_new = pd.read_csv(r"../data/SD-3X_rocktype.csv")
x_new = data.iloc[:, 0:6].values
y_new = data.iloc[:, 6].values
y_new[y_new == 4] = 0
x_new = minmax.fit_transform(x_new)
predicted_y_new = [predict(instance, p_vectors, taggings, labels) for instance in x_new]

from sklearn.metrics import classification_report

print (classification_report(y_new, predicted_y_new, target_names=['0', '1', '2', '3']))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.97      0.91      0.94       558
#           1       0.90      0.68      0.78       165
#           2       0.38      0.71      0.50       139
#           3       0.81      0.73      0.77       453
#
# avg / total       0.84      0.80      0.81      1315

# %% [markdown]
# # Next SOM

# %%
# Training the SOM
from minisom import MiniSom
som2 = MiniSom(x = 10, y = 10, input_len = 6, sigma = 1.0, learning_rate = 0.5)
som2.random_weights_init(x_train)
som2.train_random(data = x_train, num_iteration = 100)

# %%
labels2 = np.zeros((4, 10, 10))
propa2 = np.zeros((4, 10, 10))

# %%
# Visualizing the results
from pylab import bone, pcolor, colorbar, plot, show
bone()
pcolor(som2.distance_map().T)
colorbar()
markers = ['v', 's', 'o', '4']
colors = ['r', 'g', 'b', 'y']
for i, x in enumerate(x_train):
    w = som2.winner(x)
    plot(w[0] + 0.5,
         w[1] + 0.5,
         markers[y_train[i]],
         markeredgecolor = colors[y_train[i]],
         markerfacecolor = 'None',
         markersize = 10,
         markeredgewidth = 2)
    if y_train[i] == 0:
        labels2[0, w[0], w[1]] += 1
    elif y_train[i] == 1:
        labels2[1, w[0], w[1]] += 1
    elif y_train[i] == 2:
        labels2[2, w[0], w[1]] += 1
    elif y_train[i] == 3:
        labels2[3, w[0], w[1]] += 1
show()

# %%
for i in range(4):
    for j in range(10):
        for k in range(10):
            total = labels2[0, j, k] + labels2[1, j, k] + labels2[2, j, k] + labels2[3, j, k]
            if total == 0. :
                continue
            else:
                propa2[i, j, k] = labels2[i, j, k] / total
                propa2[i, j, k] = round(propa2[i, j, k], 2)

# %%
p_vectors2 = som2.weights

# %%
taggings2 = np.zeros((10, 10))
for i in range(10):
    for j in range(10):
        tmp = np.array([labels2[0][i][j], labels2[1][i][j], labels2[2][i][j], labels2[3][i][j]])
        sort = tmp.argsort()
        if (tmp[sort[3]] <= tmp[sort[2]] * 5): # must be improve
            taggings2[i][j] = np.random.choice([sort[3], sort[2]])
        else:
            taggings2[i][j] = sort[3]

# %%
predicted_y2 = [predict(instance, p_vectors2, taggings2, labels2) for instance in x_test]

from sklearn.metrics import classification_report

print (classification_report(y_test, predicted_y2, target_names=['0','1', '2', '3']))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.93      0.94      0.94        54
#           1       0.84      0.91      0.87        23
#           2       0.50      0.50      0.50         8
#           3       0.86      0.81      0.84        47
#
# avg / total       0.86      0.86      0.86       132

# %% [markdown]
# # Next SOM

# %%
# Training the SOM
from minisom import MiniSom
som3 = MiniSom(x = 10, y = 10, input_len = 6, sigma = 1.0, learning_rate = 0.5)
som3.random_weights_init(x_train)
som3.train_random(data = x_train, num_iteration = 100)

# %%
labels3 = np.zeros((4, 10, 10))
propa3 = np.zeros((4, 10, 10))

# %%
# Visualizing the results
from pylab import bone, pcolor, colorbar, plot, show
bone()
pcolor(som3.distance_map().T)
colorbar()
markers = ['v', 's', 'o', '4']
colors = ['r', 'g', 'b', 'y']
for i, x in enumerate(x_train):
    w = som3.winner(x)
    plot(w[0] + 0.5,
         w[1] + 0.5,
         markers[y_train[i]],
         markeredgecolor = colors[y_train[i]],
         markerfacecolor = 'None',
         markersize = 10,
         markeredgewidth = 2)
    if y_train[i] == 0:
        labels3[0, w[0], w[1]] += 1
    elif y_train[i] == 1:
        labels3[1, w[0], w[1]] += 1
    elif y_train[i] == 2:
        labels3[2, w[0], w[1]] += 1
    elif y_train[i] == 3:
        labels3[3, w[0], w[1]] += 1
show()

# %%
for i in range(4):
    for j in range(10):
        for k in range(10):
            total = labels3[0, j, k] + labels3[1, j, k] + labels3[2, j, k] + labels3[3, j, k]
            if total == 0. :
                continue
            else:
                propa3[i, j, k] = labels3[i, j, k] / total
                propa3[i, j, k] = round(propa3[i, j, k], 2)

# %%
p_vectors3 = som3.weights

# %%
taggings3 = np.zeros((10, 10))
for i in range(10):
    for j in range(10):
        tmp = np.array([labels3[0][i][j], labels3[1][i][j], labels3[2][i][j], labels3[3][i][j]])
        sort = tmp.argsort()
        if (tmp[sort[3]] <= tmp[sort[2]] * 5): # must be improve
            taggings3[i][j] = np.random.choice([sort[3], sort[2]])
        else:
            taggings3[i][j] = sort[3]

# %%
predicted_y3 = [predict(instance, p_vectors3, taggings3, labels3) for instance in x_test]

from sklearn.metrics import classification_report

print (classification_report(y_test, predicted_y3, target_names=['0','1', '2', '3']))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.91      0.89      0.90        54
#           1       0.84      0.91      0.87        23
#           2       0.58      0.88      0.70         8
#           3       0.83      0.74      0.79        47
#
# avg / total       0.85      0.84      0.84       132

# %%
ensemble = [np.asarray(predicted_y1), np.asarray(predicted_y2), np.asarray(predicted_y3)]

# %%
predict = [np.bincount([ensemble[j][i] for j in range(3)]).argmax() for i in range(len(ensemble[1]))]

# %%
print (classification_report(y_test, predict, target_names=['0','1', '2', '3']))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.94      0.91      0.92        54
#           1       0.83      0.87      0.85        23
#           2       0.67      0.75      0.71         8
#           3       0.85      0.85      0.85        47
#
# avg / total       0.87      0.87      0.87       132

# %%
mapping = som.win_map(x_train)
mapping2 = som2.win_map(x_train)
mapping3 = som3.win_map(x_train)

# %%
result = np.array([])
for sample in x_test:
    pos1 = find_closest(sample, p_vectors, labels)
    pos2 = find_closest(sample, p_vectors2, labels2)
    pos3 = find_closest(sample, p_vectors3, labels3)
    l1 = len(mapping[pos1])
    l2 = len(mapping[pos2])
    l3 = len(mapping[pos3])
#     (pro1, pro2, pro3, pro4) = ((l1*propa[pos1]))
    pro1 = (l1*propa[0, pos1[0], pos1[1]] + l2*propa2[0, pos2[0], pos2[1]] + l3*propa3[0, pos3[0], pos3[1]])/(l1+l2+l3)
    pro2 = (l1*propa[1, pos1[0], pos1[1]] + l2*propa2[1, pos2[0], pos2[1]] + l3*propa3[1, pos3[0], pos3[1]])/(l1+l2+l3)
    pro3 = (l1*propa[2, pos1[0], pos1[1]] + l2*propa2[2, pos2[0], pos2[1]] + l3*propa3[2, pos3[0], pos3[1]])/(l1+l2+l3)
    pro4 = (l1*propa[3, pos1[0], pos1[1]] + l2*propa2[3, pos2[0], pos2[1]] + l3*propa3[3, pos3[0], pos3[1]])/(l1+l2+l3)
    tmp = np.argmax(np.array([pro1, pro2, pro3, pro4]))
    result = np.append(result, tmp)

# %%
from sklearn.metrics import classification_report

print (classification_report(y_test, result, target_names=['0','1', '2', '3']))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.98      0.89      0.93        54
#           1       0.95      0.83      0.88        23
#           2       0.70      0.88      0.78         8
#           3       0.83      0.94      0.88        47
#
# avg / total       0.90      0.89      0.90       132
